# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
import warnings

warnings.filterwarnings("ignore")

# %%
# %ls data/
# Out:
# '1024px-Hubble_Interacting_Galaxy_AM_0500-620_(2008-04-24).jpg'
#  bar.vl.json
#  Dockerfile
# 'Football teams.csv'
#  iris.csv
#  japan_meterological_agency_201707211555.json
#  Museums_in_DC.geojson
#  README.md
#  zika_assembled_genomes.fasta

# %%
path = 'data/Football teams.csv'
df = pd.read_csv(path)
df
# Out:
#                    Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0       Manchester City  Premier League     83      15.8            46
# 1         Bayern Munich      Bundesliga     99      17.1            44
# 2   Paris Saint-Germain         Ligue 1     86      15.0            73
# 3             Barcelona          LaLiga     85      15.3            68
# 4           Real Madrid          LaLiga     67      14.4            57
# ..                  ...             ...    ...       ...           ...
# 93     Sheffield United  Premier League     20       8.5            73
# 94              Crotone         Serie A     45       9.5            85
# 95            Benevento         Serie A     40      11.0            90
# 96                Dijon         Ligue 1     25       9.2            75
# 97           Schalke 04      Bundesliga     25       8.9            70
#
#     red_cards  Possession%  Pass%  AerialsWon  Rating
# 0           2         60.8   89.4        12.8    7.01
# ...

# %%
df.head(15)
# Out:
#                    Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0       Manchester City  Premier League     83      15.8            46
# 1         Bayern Munich      Bundesliga     99      17.1            44
# 2   Paris Saint-Germain         Ligue 1     86      15.0            73
# 3             Barcelona          LaLiga     85      15.3            68
# 4           Real Madrid          LaLiga     67      14.4            57
# 5     Manchester United  Premier League     73      13.8            64
# 6              Juventus         Serie A     77      15.7            76
# 7           Aston Villa  Premier League     55      13.7            63
# 8     Borussia Dortmund      Bundesliga     75      14.6            43
# 9       Atletico Madrid          LaLiga     67      12.1           100
# 10             Atalanta         Serie A     90      16.3            66
# 11              Chelsea  Premier League     58      14.6            49
# ...

# %%
df.tail()
# Out:
#                 Team      Tournament  Goals  Shots pg  yellow_cards  \
# 93  Sheffield United  Premier League     20       8.5            73
# 94           Crotone         Serie A     45       9.5            85
# 95         Benevento         Serie A     40      11.0            90
# 96             Dijon         Ligue 1     25       9.2            75
# 97        Schalke 04      Bundesliga     25       8.9            70
#
#     red_cards  Possession%  Pass%  AerialsWon  Rating
# 93          3         43.0   76.9        19.1    6.46
# 94          4         47.2   80.4        12.7    6.43
# 95          5         44.2   77.7        13.4    6.43
# 96          5         46.9   80.0        14.3    6.42
# 97          2         46.2   76.5        15.6    6.41

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
goals = df[['Goals']]
goals
# Out:
#     Goals
# 0      83
# 1      99
# 2      86
# 3      85
# 4      67
# ..    ...
# 93     20
# 94     45
# 95     40
# 96     25
# 97     25
#
# [98 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Team', 'Tournament', 'Goals', 'Shots pg', 'yellow_cards', 'red_cards',
#        'Possession%', 'Pass%', 'AerialsWon', 'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          98 non-null     object
#  1   Tournament    98 non-null     object
#  2   Goals         98 non-null     int64
#  3   Shots pg      98 non-null     float64
#  4   yellow_cards  98 non-null     int64
#  5   red_cards     98 non-null     int64
#  6   Possession%   98 non-null     float64
#  7   Pass%         98 non-null     float64
#  8   AerialsWon    98 non-null     float64
#  9   Rating        98 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 7.8+ KB

# %%
df.describe()
# Out:
#            Goals   Shots pg  yellow_cards  red_cards  Possession%      Pass%  \
# count  98.000000  98.000000     98.000000  98.000000    98.000000  98.000000
# mean   52.183673  11.851020     69.704082   3.336735    49.995918  80.441837
# std    16.445691   2.149718     15.137316   2.148814     4.890068   4.690172
# min    20.000000   7.100000     40.000000   0.000000    38.500000  66.500000
# 25%    40.250000  10.325000     60.000000   2.000000    46.225000  78.025000
# 50%    50.000000  11.450000     67.500000   3.000000    49.750000  80.800000
# 75%    61.750000  13.350000     80.000000   4.750000    52.850000  83.450000
# max    99.000000  17.100000    117.000000  10.000000    62.400000  89.700000
#
#        AerialsWon     Rating
# count   98.000000  98.000000
# mean    16.006122   6.646122
# std      3.078955   0.132148
# min      9.500000   6.410000
# 25%     14.025000   6.540000
# 50%     16.100000   6.630000
# 75%     17.850000   6.730000
# max     26.800000   7.010000

# %%
ndf = df[['Team', 'Tournament', 'Goals', 'Rating']]
ndf
# Out:
#                    Team      Tournament  Goals  Rating
# 0       Manchester City  Premier League     83    7.01
# 1         Bayern Munich      Bundesliga     99    6.95
# 2   Paris Saint-Germain         Ligue 1     86    6.88
# 3             Barcelona          LaLiga     85    6.87
# 4           Real Madrid          LaLiga     67    6.86
# ..                  ...             ...    ...     ...
# 93     Sheffield United  Premier League     20    6.46
# 94              Crotone         Serie A     45    6.43
# 95            Benevento         Serie A     40    6.43
# 96                Dijon         Ligue 1     25    6.42
# 97           Schalke 04      Bundesliga     25    6.41
#
# [98 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Team            0
# Tournament      0
# Goals           0
# Shots pg        0
# yellow_cards    0
# red_cards       0
# Possession%     0
# Pass%           0
# AerialsWon      0
# Rating          0
# dtype: int64

# %%
df.groupby('Tournament')['Team'].nunique()
# Out:
# Tournament
# Bundesliga        18
# LaLiga            20
# Ligue 1           20
# Premier League    20
# Serie A           20
# Name: Team, dtype: int64

# %%
Liga= df.loc[df.Tournament=='LaLiga']

# %%
Liga.head()
# Out:
#                Team Tournament  Goals  Shots pg  yellow_cards  red_cards  \
# 3         Barcelona     LaLiga     85      15.3            68          2
# 4       Real Madrid     LaLiga     67      14.4            57          2
# 9   Atletico Madrid     LaLiga     67      12.1           100          0
# 29          Sevilla     LaLiga     53      12.1            75          2
# 37       Villarreal     LaLiga     60      10.7            65          5
#
#     Possession%  Pass%  AerialsWon  Rating
# 3          62.4   89.7        10.6    6.87
# 4          57.7   87.7        11.8    6.86
# 9          51.8   83.1        14.4    6.84
# 29         58.7   86.2        16.6    6.70
# 37         54.3   84.4        13.0    6.66

# %%
Liga[['Team','Goals']].sort_values(by='Goals',ascending=False)[:5].plot(kind='bar',x='Team',y="Goals",cmap='Set2')
plt.title("Goles totales de los Mejores 5 Equipos de LaLiga",fontsize=15)
plt.show()

# %%
sns.jointplot(x='Shots pg',y='Team',data=Liga)
plt.title("Tiros por Juego vs Equipo en LaLiga",fontsize=15,loc="right")
plt.show()

# %%
top_shots_pg=Liga[['Team','Goals','Shots pg']]

# %%
top_shots_pg.head()
# Out:
#                Team  Goals  Shots pg
# 3         Barcelona     85      15.3
# 4       Real Madrid     67      14.4
# 9   Atletico Madrid     67      12.1
# 29          Sevilla     53      12.1
# 37       Villarreal     60      10.7

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='Team',y='Goals',data=top_shots_pg[:5])
plt.title("Line Plot de Goles vs Equipo en LaLiga",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,7))
labels = top_shots_pg.index
plt.pie(x='Shots pg',data=top_shots_pg,labels='Team',startangle=90, autopct='%.1f%%')
plt.title("Tiros por Juego de cada equipo en LaLiga \n 2020/21 Temporada Completa", fontsize = 24) 

plt.tight_layout() 
plt.show()

# %%
LaLiga_possesion=Liga.sort_values(by='Possession%',ascending=False)

# %%
LaLiga_possesion.head()
# Out:
#              Team Tournament  Goals  Shots pg  yellow_cards  red_cards  \
# 3       Barcelona     LaLiga     85      15.3            68          2
# 29        Sevilla     LaLiga     53      12.1            75          2
# 4     Real Madrid     LaLiga     67      14.4            57          2
# 37     Villarreal     LaLiga     60      10.7            65          5
# 38  Real Sociedad     LaLiga     59      11.3            81          1
#
#     Possession%  Pass%  AerialsWon  Rating
# 3          62.4   89.7        10.6    6.87
# 29         58.7   86.2        16.6    6.70
# 4          57.7   87.7        11.8    6.86
# 37         54.3   84.4        13.0    6.66
# 38         53.7   80.8        17.9    6.65

# %%
sns.barplot(x='Team',y='Possession%',data=LaLiga_possesion[:5],palette='Paired')
plt.title("Posesion Maxima de LaLiga", fontsize=15)
plt.show()

# %%
sns.catplot(x='Goals',y='Shots pg',data=Liga[:5],hue="Team")
plt.title("Goles vs Tiros por Partido (Mejores 5)",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,10))
tournaments=df.groupby('Tournament')['Goals','Pass%','Possession%','Shots pg'].sum().plot(kind='bar')
plt.title(" Comparacion de los torneos", fontsize=15)
plt.show()

# %%
sns.scatterplot(x='Tournament',y='Goals',data=df)
plt.title("Torneo y sus Goles")
plt.show()
